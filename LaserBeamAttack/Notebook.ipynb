# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from utils import Line, LaserBeam, add_laser_to_image

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

# %%
first = x_train[1].copy()

# %%
plt.imshow(first)

# %%
lb1 = LaserBeam(550, 2, Line(0, 15))
lb2 = LaserBeam(650, 3, Line(10, 15))

# %%
plt.imshow(add_laser_to_image(first, lb1))

# %%
plt.imshow(add_laser_to_image(first, lb2))
